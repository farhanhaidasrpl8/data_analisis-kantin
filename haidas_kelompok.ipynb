# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanhaidasrpl8/data_analisis-kantin/blob/main/haidas_kelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tugas Analisis 1:
import numpy as np
harga = np.array([5000, 8000, 3000, 12000, 4500])
print('Rata-rata harga:', harga.mean())
print('Harga tertinggi:', harga.max())
print('Harga setelah diskon 10%:', harga * 0.9)

print(harga * 0.9 )
# Out:
# Rata-rata harga: 6500.0
# Harga tertinggi: 12000
# Harga setelah diskon 10%: [ 4500.  7200.  2700. 10800.  4050.]
# [ 4500.  7200.  2700. 10800.  4050.]

# %%
import numpy as np
harga = np.array([5000,7000,3000])
print('Rata-rata harga:', harga.mean())
print('Harga tertinggi:', harga.max())
print('Harga setelah diskon 10%:', harga * 0.9)

print(harga * 0.9)

#Berhasil karena NumPy otomatis mengalikan setiap angka di dalamnya secara langsung (element-wise)

#sementara python list biasa hanya bisa digunakan untuk menduplikasi/mengulang list (replikasi)
#dengan angka bulat (integer), bukan angka desimal (float).
# Out:
# Rata-rata harga: 5000.0
# Harga tertinggi: 7000
# Harga setelah diskon 10%: [4500. 6300. 2700.]
# [4500. 6300. 2700.]

# %% [markdown]
# jawaban
#
# Berhasil soalnya NumPy otomatis mengalikan setiap angka di secara langsung (element-wise)
#
# sementara python list biasa cuma bisa digunakan untuk menduplikasi/mengulang list (replikasi)
# dengan angka bulat (integer), bukan angka desimal (float).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Latihan 2: Membuat Series & DataFrame
import pandas as pd
data_kantin = {
'menu': ['Nasi Goreng', 'Es Teh', 'Mie Ayam', 'Es Teh', None],
'harga': [12000, 4000, 10000, 4000, 8000],
'terjual': [23, 40, None, 35, 18]
}
df = pd.DataFrame(data_kantin)
print(df)
# Out:
#           menu  harga  terjual
# 0  Nasi Goreng  12000     23.0
# 1       Es Teh   4000     40.0
# 2     Mie Ayam  10000      NaN
# 3       Es Teh   4000     35.0
# 4         None   8000     18.0

# %%
df.to_csv('data_kantin.csv', index=False)
print('File data_kantin.csv telah berhasil dibuat.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_682/1367058144.py in <cell line: 0>()
# ----> 1 df.to_csv('data_kantin.csv', index=False)
#       2 print('File data_kantin.csv telah berhasil dibuat.')
#
# NameError: name 'df' is not defined

# %% [markdown]
#  di kolom menu
#  (indeks 4) dan kolom terjual (indeks 2)
#
#  Risiko Tanpa Dibersihkan
#
# -Salah Hitung
# -Program Error
# -Kesimpulan Salah

# %%
#Latihan 3: Data Loading & Inspection
df = pd.read_csv('data_kantin.csv')
print(df.head()) # 5 baris pertama
print(df.info()) # tipe data & jumlah non-null tiap kolom
print(df.describe()) # statistik ringkas kolom numerik
print(df.shape) # jumlah (baris, kolom)
#Dari hasil df.info(), kolom mana yang jumlah
#non-null-nya lebih sedikit dari jumlah baris total? Apa artinya?

# %% [markdown]
# Cara melihatnya: Periksa tabel ringkasan df.info() dan cari kolom yang angka pada kolom Non-Null Count-nya lebih kecil daripada total baris (RangeIndex).
#
# Artinya: Kolom tersebut memiliki data yang kosong atau hilang (missing values / NaN), yang umumnya terjadi karena data tidak wajib diisi, terlewat saat pencatatan, atau ada kesalahan input.

# %%
#Latihan 4: Menangani Missing Value
print(df.isnull().sum()) # jumlah data kosong tiap kolom
df['terjual'] = df['terjual'].fillna(0) # isi kekosongan dengan 0
df = df.dropna(subset=['menu']) # hapus baris jika kolom menu kosong

#Mengapa pada contoh di atas kolom terjual diisi (fillna) sedangkan baris
#dengan menu kosong justru dihapus (dropna)? Diskusikan alasan logisnya.

# %% [markdown]
# terjual diisi 0: Kosong berarti tidak ada penjualan, sehingga aman untuk perhitungan.
#
# menu dihapus: Nama menu adalah identitas utama; jika kosong, data kehilangan arti dan tidak valid.

# %%
#Latihan 5: Menangani Duplikat dan Tipe Data
print(df.duplicated().sum()) # jumlah baris duplikat
df = df.drop_duplicates()
df['harga'] = df['harga'].astype(int) # memastikan tipe data harga adalah integer
print(df.dtypes)
#Tugas Analisis 5: Setelah drop_duplicates(), berapa jumlah baris dataset sekarang dibanding
#sebelumnya? Mengapa penting memastikan tipe data (dtypes) sudah benar
#sebelum data dianalisis lebih lanjut?

# %% [markdown]
# Jumlah baris: Sama atau lebih sedikit (berkurang jika ada duplikat yang terhapus).
#
# Pentingnya tipe data: Agar operasi matematika dan analisis berjalan akurat tanpa error.

# %%
#Latihan 6: Data Manipulation (Filtering, Sorting, Groupby)
laris = df[df['terjual'] > 20] # filtering
urut = df.sort_values(by='terjual', ascending=False) # sorting
df['total_pendapatan'] = df['harga'] * df['terjual'] # kolom turunan
ringkasan = df.groupby('menu')['total_pendapatan'].sum() # agregasi
print(ringkasan)
#Tugas Analisis 6: Dari hasil groupby di atas, menu apa yang
#menghasilkan total_pendapatan tertinggi? Bagaimana informasi ini
#bisa membantu pengambilan keputusan di kantin sekolah?

# %% [markdown]
# Menu tertinggi: Nasi Goreng (dengan total pendapatan tertinggi berdasarkan data).
#
# Manfaat pengambilan keputusan: Membantu pengelola kantin memprioritaskan stok bahan baku, mengoptimalkan keuntungan, dan fokus pada strategi penjualan menu yang paling diminati siswa.
